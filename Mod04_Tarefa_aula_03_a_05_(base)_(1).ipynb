# %% [markdown]
# <a href="https://colab.research.google.com/github/Adelson021/Proj01/blob/main/Mod04_Tarefa_aula_03_a_05_(base)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np


np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

# Dicionário com o número de questões por assunto
num_questoes = {
    'Matemática': 24,
    'Português': 18,
    'Geografia': 8,
    'Inglês': 8,
    'História': 8,
    'Física': 12,
    'Química': 12
}

# Função para calcular o percentual de acertos
def calcular_percentual(df, assunto):
    total_questoes = num_questoes[assunto]
    df['Percentual_acerto'] = (df['Qt_acertos'] / total_questoes) * 100

# Aplicando a função para cada DataFrame
calcular_percentual(df_mat, 'Matemática')
calcular_percentual(df_por, 'Português')
calcular_percentual(df_geo, 'Geografia')
calcular_percentual(df_ing, 'Inglês')
calcular_percentual(df_his, 'História')
calcular_percentual(df_fis, 'Física')
calcular_percentual(df_qui, 'Química')

# Exibindo os resultados
print("Matemática:")
print(df_mat.head())
print("\nPortuguês:")
print(df_por.head())
print("\nGeografia:")
print(df_geo.head())
print("\nInglês:")
print(df_ing.head())
print("\nHistória:")
print(df_his.head())
print("\nFísica:")
print(df_fis.head())
print("\nQuímica:")
print(df_qui.head())
# Out:
# Matemática:
#    Qt_acertos  Percentual_acerto
# 0           6          25.000000
# 1          19          79.166667
# 2          14          58.333333
# 3          10          41.666667
# 4           7          29.166667
#
# Português:
#    Qt_acertos  Percentual_acerto
# 0           7          38.888889
# 1          10          55.555556
# 2          16          88.888889
# 3           7          38.888889
# 4           2          11.111111
#
# Geografia:
#    Qt_acertos  Percentual_acerto
# 0           7               87.5
# 1           0                0.0
# 2           0                0.0
# 3           3               37.5
# 4           2               25.0
#
# Inglês:
#    Qt_acertos  Percentual_acerto
# 0           3               37.5
# 1           0                0.0
# 2           5               62.5
# 3           4               50.0
# 4           7               87.5
#
# História:
#    Qt_acertos  Percentual_acerto
# 0           1               12.5
# ...

# %%
# 2) Seu código aqui

# Calculando o total de acertos de cada aluno
df_total_acertos = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui

df_total_acertos
# Out:
#     Qt_acertos  Percentual_acerto
# 0           35         293.055556
# 1           48         293.055556
# 2           50         363.888889
# 3           32         234.722222
# 4           30         252.777778
# ..         ...                ...
# 95          34         297.222222
# 96          27         234.722222
# 97          40         248.611111
# 98          40         343.055556
# 99          42         291.666667
#
# [100 rows x 2 columns]

# %%
# 3) Seu código aqui

# Número total de questões no exame
total_questoes_exame = sum(num_questoes.values())

# Calculando o percentual geral de cada aluno
df_percentual_geral = (df_total_acertos / total_questoes_exame) * 100

df_percentual_geral
# Out:
#     Qt_acertos  Percentual_acerto
# 0    38.888889         325.617284
# 1    53.333333         325.617284
# 2    55.555556         404.320988
# 3    35.555556         260.802469
# 4    33.333333         280.864198
# ..         ...                ...
# 95   37.777778         330.246914
# 96   30.000000         260.802469
# 97   44.444444         276.234568
# 98   44.444444         381.172840
# 99   46.666667         324.074074
#
# [100 rows x 2 columns]

# %%
# 4) Seu código aqui

# Nota de corte para a segunda fase
nota_corte = 45

# Contando quantos alunos tiveram nota maior que 45
alunos_aprovados = (df_percentual_geral > nota_corte).sum()

alunos_aprovados
# Out:
# Qt_acertos            47
# Percentual_acerto    100
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui

# Verificando se algum aluno zerou em Matemática, Física ou Química
alunos_desqualificados = df_total_acertos[(df_mat['Qt_acertos'] == 0) | (df_fis['Qt_acertos'] == 0) | (df_qui['Qt_acertos'] == 0)]

# Exibindo os resultados
print(alunos_desqualificados)

# Quantidade de alunos desqualificados
quantidade_desqualificados = len(alunos_desqualificados)
print("Número de alunos desqualificados:", quantidade_desqualificados)

# Calculando a média dos alunos desqualificados em História e Geografia
media_hist_geog_desqualificados = alunos_desqualificados[['Qt_acertos', 'Qt_acertos']].mean()
print("Média em História e Geografia dos alunos desqualificados:")
print(media_hist_geog_desqualificados)

# Filtrando os alunos que passaram para a segunda fase
alunos_segunda_fase = df_percentual_geral[df_percentual_geral > nota_corte]

# Exibindo o DataFrame com os alunos que passaram para a segunda fase
print("DataFrame com os alunos que passaram para a segunda fase:")
print(alunos_segunda_fase.head())
# Out:
#     Qt_acertos  Percentual_acerto
# 3           32         234.722222
# 6           29         295.833333
# 10          31         219.444444
# 12          42         290.277778
# 14          31         236.111111
# 20          53         386.111111
# 25          27         259.722222
# 26          40         311.111111
# 27          50         347.222222
# 33          39         290.277778
# 35          48         365.277778
# 49          19         130.555556
# 56          39         354.166667
# 65          24         211.111111
# 66          31         276.388889
# 72          50         384.722222
# 73          37         297.222222
# 74          39         306.944444
# 84          26         176.388889
# 89          63         481.944444
# 92          40         280.555556
# 94          25         231.944444
# 98          40         343.055556
# Número de alunos desqualificados: 23
# Média em História e Geografia dos alunos desqualificados:
# Qt_acertos    37.173913
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-19209749-f210-43b5-bc13-fd762d9417b7.c000.csv'

# %%
df = pd.read_csv(arquivo, sep=';')
df.head(4)
# Out:
#                                  document_id  \
# 0  3edcbfd0-d834-4cb8-94b4-c7f704e8cdd1-i0b0
# 1  156ae0af-30f5-4456-9978-c29564bdf24e-i0b0
# 2  56b824f5-a429-445f-9323-b45563dcb337-i0b0
# 3  15756059-201f-4f29-bb53-b3004a09097a-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  7c2c79916c69eba40d899dfc000138f078fa5c200353a5...            29.0
# 1  35ffb7ba427aacfe43f03c350ec04223f9cc271379d3f3...            53.0
# 2  2812fd2e564a9a5fdf8f24bf24c7ca584ac60785392940...            23.0
# 3  b213086b2f44dc7414c30fc147bbef0c48e6777a14ca6b...            30.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1992-07-21                          F                      4.0
# 1              1968-12-30                          M                      3.0
# 2              1998-04-06                          M                     99.0
# ...

# %%
# 1) Sua solução aqui
df['vacina_nome'].unique()
# Out:
# array(['COVID-19 PFIZER - COMIRNATY',
#        'COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD',
#        'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#        'COVID-19 PFIZER - COMIRNATY BIVALENTE', 'INF3',
#        'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#        'COVID-19 JANSSEN - Ad26.COV2.S',
#        'COVID-19 PEDIÁTRICA - PFIZER COMIRNATY',
#        'COVID-19 SINOVAC - CORONAVAC',
#        'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA MENOR DE 5 ANOS',
#        'COVID-19 ASTRAZENECA - ChAdOx1-S', 'VVBN', nan], dtype=object)

# %%
df['vacina_nome'].nunique()
# Out:
# 12

# %%
# 2)

df['paciente_id'].nunique()
# Out:
# 316440

# %%
# 3)
df_primeira_dose = df[df['vacina_descricao_dose'] == '1ª Dose']
df_primeira_dose['paciente_id'].nunique()
# Out:
# 143189

# %%
# 3)
df['vacina_descricao_dose'].unique()
# Out:
# array(['1ª Dose', 'Reforço', '2ª Dose', '2º Reforço', 'Única',
#        'Dose Adicional', '3º Reforço', 'Revacinação', '3ª Dose',
#        '1º Reforço', '1ª Dose Revacinação', 'Dose', '2ª Dose Revacinação',
#        '3ª Dose Revacinação', '4ª Dose Revacinação',
#        '5ª Dose Revacinação'], dtype=object)

# %%
primeira_dose = df['vacina_descricao_dose'].unique()[0]
primeira_dose
# Out:
# '1ª Dose'

# %%
df.loc[df['vacina_descricao_dose'] == primeira_dose, 'paciente_id'].nunique()
# Out:
# 143189

# %%
# 4)
df_menor_18 = df[df['paciente_idade'] < 18]
df_menor_18['paciente_id'].nunique()
# Out:
# 68187

# %%
# 5)
df['estabelecimento_razaoSocial'].unique()
# Out:
# array(['PREFEITURA MUNICIPAL DE RIO BRANCO',
#        'PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL',
#        'PREFEITURA MUNICIPAL DE TARAUACA',
#        'DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO JURUA',
#        'PREFEITURA MUN DE MAL THAUMATURGO',
#        'PREFEITURA MUNICIPAL DE MANCIO LIMA',
#        'DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA',
#        'SECRETARIA MUNCIPAL DE SAUDE',
#        'PREFEITURA MUNICIPAL DE MANUEL URBANO',
#        'PREFEITURA MUNICIPAL DE FEIJO', 'SECRETARIA MUNICIPAL DE SAUDE',
#        'PREFEITURA MUNICIPAL DE SENA MADUREIRA',
#        'PREFEITURA MUNICIPAL DE ACRELANDIA',
#        'PREFEITURA MUNICIPAL DE BRASILEIA',
#        'PREFEITURA MUNICIPAL DE SENADOR GUIOMARD',
#        'PREFEITURA MUNICIPAL DE XAPURI', 'PREFEITURA MUNICIPAL DE SAUDE',
#        'MUNICIPIO DE MARECHAL THAUMATURGO',
#        'PREFEITURA MUNICIPAL DE ASSIS BRASIL', 'REDE DE FRIOS',
#        'PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS',
# ...

# %%
df['estabelecimento_razaoSocial'].nunique()
# Out:
# 62

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_menor_18_copy = df[df['paciente_idade'] < 18].copy()
df_menor_18_copy.head()
# Out:
#                                   document_id  \
# 17  161ef5fc-74fd-4aa1-83de-f4667c577011-i0b0
# 27  16df29ce-122b-432e-ad17-846b86c88ebe-i0b0
# 31  16f52dec-b461-4c90-9175-7e0913026ecc-i0b0
# 36  f4b27c98-d30d-4f12-bc4d-cac99bc58604-i0b0
# 48  792205bf-96f4-45c1-a6ba-ec771cc7e94d-i0b0
#
#                                           paciente_id  paciente_idade  \
# 17  84e8fedc8def2e4736eda9d20dcc7925241a313f4158da...            12.0
# 27  03cb4392a122b4742c5af43061fb842d1165cc7b6a0f59...            14.0
# 31  8c8440247fba8711c2b8c89ad1695deccd9189d335aa75...             5.0
# 36  f0c1d9581fc70baf0f21bf670aacd476f158d663b85544...            11.0
# 48  6a143521214776d91a9788223bfe0e3c21fd6277aa6b28...            13.0
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 17              2009-05-05                          M
# 27              2007-08-15                          M
# 31              2017-12-15                          M
# ...

# %%
# 2)
lista_colunas = df_menor_18_copy.columns.tolist()
lista_colunas
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem']

# %%
# 3)
contagem_por_categoria = df_menor_18_copy['vacina_categoria_nome'].value_counts()
contagem_por_categoria
# Out:
# vacina_categoria_nome
# Faixa Etária                                      47480
# Povos Indígenas                                    4665
# Outros                                             3755
# Povos e Comunidades Tradicionais                    819
# Trabalhadores de Saúde                              254
# Comorbidades                                         56
# População Privada de Liberdade                       53
# Gestantes                                            42
# Pessoas com Deficiência                              11
# Pessoas Institucionalizadas                           3
# Trabalhadores da Educação                             2
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Name: count, dtype: int64

# %%
# 4)
estabelecimento = [
    'estabelecimento_valor',
    'estabelecimento_razaoSocial',
    'estalecimento_noFantasia',
    'estabelecimento_municipio_codigo',
    'estabelecimento_municipio_nome',
    'estabelecimento_uf'
]
lista_variaveis = estabelecimento

# Verifica se as colunas existem no DataFrame antes de fatiar
for col in lista_variaveis:
    if col not in df_menor_18.columns:
        print(f"Aviso: Coluna '{col}' não encontrada no DataFrame.")

# Se você ainda quiser prosseguir, mesmo que algumas colunas estejam faltando, você pode filtrar a lista:
lista_variaveis_existentes = [col for col in lista_variaveis if col in df_menor_18_copy.columns]

df_menor_lista = df_menor_18_copy.loc[:, lista_variaveis]
df_menor_lista
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 17                    2002132        PREFEITURA MUN DE MAL THAUMATURGO
# 27                    3544915            PREFEITURA MUNICIPAL DE FEIJO
# 31                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 36                    3006166       PREFEITURA MUNICIPAL DE ACRELANDIA
# 48                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                      ...
# 387037                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 387038                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 387059                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 387062                2002299  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 387064                2002922            SECRETARIA MUNICIPAL DE SAUDE
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 5)
df_estabelecimentos = df_menor_18_copy.loc[:, estabelecimento]
df_estabelecimentos
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 17                    2002132        PREFEITURA MUN DE MAL THAUMATURGO
# 27                    3544915            PREFEITURA MUNICIPAL DE FEIJO
# 31                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 36                    3006166       PREFEITURA MUNICIPAL DE ACRELANDIA
# 48                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                      ...
# 387037                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 387038                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 387059                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 387062                2002299  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 387064                2002922            SECRETARIA MUNICIPAL DE SAUDE
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 6)
sem_duplicatas = df_menor_18_copy.drop_duplicates(subset="estabelecimento_razaoSocial", keep="first")
lista_estabelecimentos = sem_duplicatas.to_dict(orient="records")
lista_estabelecimentos
# Out:
# [{'document_id': '161ef5fc-74fd-4aa1-83de-f4667c577011-i0b0',
#   'paciente_id': '84e8fedc8def2e4736eda9d20dcc7925241a313f4158dad3c6895e1d212d0458',
#   'paciente_idade': 12.0,
#   'paciente_dataNascimento': '2009-05-05',
#   'paciente_enumSexoBiologico': 'M',
#   'paciente_racaCor_codigo': 4.0,
#   'paciente_racaCor_valor': 'AMARELA',
#   'paciente_endereco_coIbgeMunicipio': 120035.0,
#   'paciente_endereco_coPais': 10.0,
#   'paciente_endereco_nmMunicipio': 'MARECHAL THAUMATURGO',
#   'paciente_endereco_nmPais': 'BRASIL',
#   'paciente_endereco_uf': 'AC',
#   'paciente_endereco_cep': 69983.0,
#   'paciente_nacionalidade_enumNacionalidade': 'B',
#   'estabelecimento_valor': 2002132,
#   'estabelecimento_razaoSocial': 'PREFEITURA MUN DE MAL THAUMATURGO',
#   'estalecimento_noFantasia': 'ESF RIBEIRINHA DR NALDIR MARIANO',
#   'estabelecimento_municipio_codigo': 120035,
#   'estabelecimento_municipio_nome': 'MARECHAL THAUMATURGO',
#   'estabelecimento_uf': 'AC',
# ...
